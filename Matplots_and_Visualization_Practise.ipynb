# %%
# Load csv
import pandas as pd
df = pd.read_csv('data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
mydataset = {'cars': ["BMW", "Volvo", "Honda"],
             'numbers':[12,15,18]}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  numbers
# 0    BMW       12
# 1  Volvo       15
# 2  Honda       18

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
a = [1,4,5]
var = pd.Series(a, index = ["B", "V", "C"])
print(var)
# Out:
# B    1
# V    4
# C    5
# dtype: int64

# %%
# dataframe to dictionaries form

data = {
    "calories": [400,300,120],
    "duration": [50,40,20]

}

df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       400        50
# 1       300        40
# 2       120        20

# %%
#Location
print(df.loc[[0,2]])
# Out:
#    calories  duration
# 0       400        50
# 2       120        20

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#analyzing dataset head - from first rows, tail - last rows default - 5rows
print(df.tail(4))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
#info()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
#Remove null values
new_df = df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
# fillna - fill the null values

# %%
#Statistics concepts:

x = df["Duration"].mode()
print(x)
# Out:
# 0    60
# dtype: int64

# %%
#Replacing Values

df.loc[5, 'Pulse'] = 122
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    122       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#duplicated values - True, no duplicates - False
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
#Correlation - corr() range from -1 to +1  > 
0.6

df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155760  0.009403  0.922717
# Pulse    -0.155760  1.000000  0.781044  0.022681
# Maxpulse  0.009403  0.781044  1.000000  0.203813
# Calories  0.922717  0.022681  0.203813  1.000000

# %%
 #Plotting  plot() method

#Pyplot show( - show the output)

import pandas as pd

import matplotlib.pyplot as plt
df = pd.read_csv('data.csv')
df.plot()
plt.show()

# %%
#Scatter plot

df.plot(kind = 'scatter', x ='Duration', y = 'Calories')
plt.show()

# %%
#histogram
df["Maxpulse"].plot(kind='hist')

# %%
#Matplotlib
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.2.2

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1,6])
y = np.array([3,250])
plt.plot(x,y)
plt.show()

# %%
x1 = np.array([2,4,6,7])
y1 = np.array([3,10,8,1])
plt.plot(x1,y1)
plt.show()

# %%
#Marker mec - marker edge color, mfc - marker face color Linewidth - change the width of line (float)
x2 = np.array([3,1,2,4])
plt.plot(x2,linewidth = '10.2')
plt.show()

# %%
y1 = np.array([1,2,3,4])
y2 = np.array([5,6,7,8])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x= np.array([100,200,300,400,500,600])
y = np.array([6,5,4,3,2,1])
plt.plot(x,y)
plt.grid(color='red', linestyle = '--', linewidth = 0.5)
plt.title("BVC COLLEGE", loc = 'left')
plt.xlabel("Total Marks")
plt.ylabel("Rank Obtained")
plt.show()

# %%
#subplot()

x = np.array([0,1,2,3])
y = np.array([50,60,70,80])
plt.subplot(1,2,1)
plt.show()

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
#Compare plots

x = np.array([1,2,3,4,5,6,7,8])
y = np.array([50,60,70,80,90,102,104,110])
sizes = np.array([1002,1004,105,1006,1007,1008,400,500])
plt.scatter(x,y, s = sizes )
plt.show()

# %%
#Bar() default width value is 0.8
x = np.array(["A", "B", "C", "D"])
y = np.array([50,60,65,82])
plt.barh(x,y, height=  0.4)
plt.show()

# %%
#Histogram - hist()

x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
#Pie chart()

x1 = np.array([12,13,14,16])
mylabels = ["Ram", "Shyam", "Ramesh", "Harish"]
plt.pie(x1, labels = mylabels)
plt.show()

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.4.1

# %%
#Constants module
from scipy import constants
print(constants.minute)
# Out:
# 60.0

# %%
#Sparse Data

from scipy.sparse import csr_matrix
ar1 = np.array([0,0,0,0,0,0,1,0,0,2])
print(csr_matrix(ar1))
# Out:
#   (0, 6)	1
#   (0, 9)	2

# %%
#Graphs

#Dijkstra Algorithm

from scipy.sparse.csgraph import dijkstra
from scipy.sparse import csr_matrix
arr = np.array([[0,1,2],[1,0,0],[2,0,0]])

newarr = csr_matrix(arr)
print(dijkstra(newarr, return_predecessors = True, indices = 0))
# Out:
# (array([0., 1., 2.]), array([-9999,     0,     0], dtype=int32))

# %%
from nltk.tokenize import word_tokenize
text = """Hello BVC College, how are you?. I am fine and hope that you are attending classes."""
tokenized_word = word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'BVC', 'College', ',', 'how', 'are', 'you', '?', '.', 'I', 'am', 'fine', 'and', 'hope', 'that', 'you', 'are', 'attending', 'classes', '.']
